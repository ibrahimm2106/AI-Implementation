# %% [markdown]
# # Lab 08 — Decision Tree Classification
# Exercise using the PastHires dataset and two supplied test samples.

# %%
from sklearn.tree import DecisionTreeClassifier, export_text
# Encode categorical columns, fit DecisionTreeClassifier, then predict the two activity samples.

# %% [markdown]
# ## Recorded output
# `Sample 1 Prediction: Hired`
#
# `Sample 2 Prediction: Not Hired`
