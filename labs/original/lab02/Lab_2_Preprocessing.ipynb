# %% [markdown]
# # Lab 02 — Data Preprocessing
# Exercise covering preview, missingness, imputation, scaling, categorical encoding and CSV export.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
df = pd.read_excel('HousingData.xlsx')
numeric = df.select_dtypes(include='number').columns
categorical = df.select_dtypes(include='object').columns
for c in numeric: df[c] = df[c].fillna(df[c].median())
for c in categorical: df[c] = df[c].fillna('Missing')
df[numeric] = StandardScaler().fit_transform(df[numeric])
df = pd.get_dummies(df, columns=categorical, drop_first=True)

# %% [markdown]
# Recorded exercise result: missing values were reduced to zero after imputation and the processed dataset was exported.
